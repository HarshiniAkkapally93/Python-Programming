# %%
import pandas as pd

# %%
Crashes_df=pd.read_csv(r'/Users/sandeepreddy/Downloads/Crashes.csv')
Persons_df=pd.read_csv(r'/Users/sandeepreddy/Downloads/Persons.csv')
Vehicles_df=pd.read_csv(r'/Users/sandeepreddy/Downloads/Vehicles.csv')
# Out:
# /Users/sandeepreddy/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (34,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/sandeepreddy/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (37) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Crashes_df.columns
# Out:
# Index(['YEAR', 'QUARTER', 'LIGHT_DESC', 'LIGHT_CODE', 'COUNTY_DESC',
#        'COUNTY_NO', 'MUNI_DESC', 'MUNI_CODE', 'JUNCTION_DESC', 'JUNCTION_CODE',
#        'COLLISION_TYPE_DESC', 'COLLISION_TYPE_CODE', 'SURF_COND_DESC',
#        'SURF_COND_CODE', 'LANE_DESC', 'LANE_CODE', 'RD_COND_DESC',
#        'RD_COND_CODE', 'RD_DIV_DESC', 'RD_DIV_CODE', 'FIX_OBJ_DESC',
#        'FIX_OBJ_CODE', 'REPORT_NO', 'REPORT_TYPE', 'WEATHER_DESC',
#        'WEATHER_CODE', 'ACC_DATE', 'ACC_TIME', 'LOC_CODE', 'SIGNAL_FLAG_DESC',
#        'SIGNAL_FLAG', 'C_M_ZONE_FLAG', 'AGENCY_CODE', 'AREA_CODE',
#        'HARM_EVENT_DESC1', 'HARM_EVENT_CODE1', 'HARM_EVENT_DESC2',
#        'HARM_EVENT_CODE2', 'RTE_NO', 'ROUTE_TYPE_CODE', 'RTE_SUFFIX',
#        'LOG_MILE', 'LOGMILE_DIR_FLAG_DESC', 'LOGMILE_DIR_FLAG',
#        'MAINROAD_NAME', 'DISTANCE', 'FEET_MILES_FLAG_DESC', 'FEET_MILES_FLAG',
#        'DISTANCE_DIR_FLAG', 'REFERENCE_NO', 'REFERENCE_TYPE_CODE',
# ...

# %%
Persons_df.head()
# Out:
#   SEX_DESC SEX_CODE     CONDITION_DESC  CONDITION_CODE  \
# 0   Female        F  Apparently Normal             1.0
# 1     Male        M                NaN             NaN
# 2   Female        F                NaN             NaN
# 3     Male        M                NaN             NaN
# 4   Female        F  Apparently Normal             1.0
#
#                    INJ_SEVER_DESC  INJ_SEVER_CODE   REPORT_NO  \
# 0                       No Injury               1  AE59920005
# 1       Non-incapacitating Injury               2  DA40650004
# 2  Possible Incapacitating Injury               3  ZU7729000P
# 3                       No Injury               1  CT8278002X
# 4                       No Injury               1  DA3660000B
#
#   OCC_SEAT_POS_DESC  OCC_SEAT_POS_CODE PED_VISIBLE_DESC  ...  \
# 0               NaN                NaN              NaN  ...
# 1  Right Front Seat                3.0              NaN  ...
# 2  Center Rear Seat                5.0              NaN  ...
# ...

# %%
Vehicles_df
# Out:
#         HARM_EVENT_DESC  HARM_EVENT_CODE CONTI_DIRECTION_DESC  \
# 0         Other Vehicle              1.0                North
# 1         Other Vehicle              1.0                North
# 2         Other Vehicle              1.0                South
# 3          Fixed Object              9.0              Unknown
# 4         Other Vehicle              1.0                 East
# ...                 ...              ...                  ...
# 1438803    Fixed Object              9.0                South
# 1438804         Unknown             99.0                 East
# 1438805   Other Vehicle              1.0                South
# 1438806   Other Vehicle              1.0                 East
# 1438807   Other Vehicle              1.0                South
#
#         CONTI_DIRECTION_CODE  DAMAGE_DESC  DAMAGE_CODE  \
# 0                          N      Unknown           99
# 1                          N  Superficial            2
# ...

# %%
df=pd.DataFrame()
df1=pd.DataFrame()

# %%
df=pd.merge(Crashes_df,Persons_df,on ='REPORT_NO',how='inner')
df
# Out:
#          YEAR_x QUARTER LIGHT_DESC  LIGHT_CODE     COUNTY_DESC  COUNTY_NO  \
# 0          2020      Q2   Daylight        1.00       Baltimore        3.0
# 1          2020      Q2        NaN        6.02  Baltimore City       24.0
# 2          2020      Q2        NaN        6.02  Baltimore City       24.0
# 3          2020      Q2        NaN        6.02  Baltimore City       24.0
# 4          2020      Q2        NaN        6.02  Baltimore City       24.0
# ...         ...     ...        ...         ...             ...        ...
# 1728667    2021      Q4   Daylight        1.00       Baltimore        3.0
# 1728668    2021      Q4   Daylight        1.00       Baltimore        3.0
# 1728669    2021      Q4        NaN        7.88        Wicomico       22.0
# 1728670    2021      Q4        NaN        7.88        Wicomico       22.0
# 1728671    2021      Q4        NaN        6.02    Anne Arundel        2.0
#
#          MUNI_DESC  MUNI_CODE     JUNCTION_DESC  JUNCTION_CODE  ...  \
# ...

# %%
df1=pd.merge(df,Vehicles_df,on ='REPORT_NO',how='inner')

# %%
df1
# Out:
#          YEAR_x QUARTER LIGHT_DESC  LIGHT_CODE     COUNTY_DESC  COUNTY_NO  \
# 0          2020      Q2   Daylight        1.00       Baltimore        3.0
# 1          2020      Q2   Daylight        1.00       Baltimore        3.0
# 2          2020      Q2        NaN        6.02  Baltimore City       24.0
# 3          2020      Q2        NaN        6.02  Baltimore City       24.0
# 4          2020      Q2        NaN        6.02  Baltimore City       24.0
# ...         ...     ...        ...         ...             ...        ...
# 3568296    2021      Q4        NaN        7.88        Wicomico       22.0
# 3568297    2021      Q4        NaN        7.88        Wicomico       22.0
# 3568298    2021      Q4        NaN        7.88        Wicomico       22.0
# 3568299    2021      Q4        NaN        7.88        Wicomico       22.0
# 3568300    2021      Q4        NaN        6.02    Anne Arundel        2.0
#
#          MUNI_DESC  MUNI_CODE     JUNCTION_DESC  JUNCTION_CODE  ...  \
# ...

# %%
df.shape
# Out:
# (1728672, 103)

# %%
Vehicles_df.shape
# Out:
# (1438808, 49)

# %%
Persons_df.shape
# Out:
# (1728652, 48)

# %%
Crashes_df.shape
# Out:
# (771145, 56)
